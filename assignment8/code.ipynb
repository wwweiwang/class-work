# %%
import matplotlib.pyplot as plt

# try it yourself 15-1

x = range(1,6)
y = [i**3 for i in x]

plt.plot(x, y)
plt.title("Cube numbers")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
x = range(1,5001)
y = [i**3 for i in x]

plt.plot(x, y)
plt.title("Cube numbers")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
# try it yourself 15-2

x = range(1,5001)
y = [i**3 for i in x]

plt.scatter(x, y, c=y, cmap=plt.cm.Blues)
plt.title("Cube numbers")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
# try it yourself 15-3
from random import choice

class RandomWalk():
    """A class to generate random walks."""
    
    def __init__(self, num_points=5000):
        """Initialize attributes of a walk."""
        self.num_points = num_points
        
        # All walks start at (0, 0).
        self.x_values = [0]
        self.y_values = [0]

    def fill_walk(self):
        """Calculate all the points in the walk."""
        
        # Keep taking steps until the walk reaches the desired length.
        while len(self.x_values) < self.num_points:
            
            # Decide which direction to go, and how far to go in that direction.
            x_direction = choice([1, -1])
            x_distance = choice([0, 1, 2, 3, 4])
            x_step = x_direction * x_distance
            
            y_direction = choice([1, -1])
            y_distance = choice([0, 1, 2, 3, 4])
            y_step = y_direction * y_distance
            
            # Reject moves that go nowhere.
            if x_step == 0 and y_step == 0:
                continue
            
            # Calculate the next x and y values.
            next_x = self.x_values[-1] + x_step
            next_y = self.y_values[-1] + y_step
            
            self.x_values.append(next_x)
            self.y_values.append(next_y)

rw = RandomWalk()
rw.fill_walk()
plt.plot(rw.x_values, rw.y_values)
plt.show()

# %%
# try it yourself 15-4
# x and y move to the same direction
class RandomWalkV2():
    """A class to generate random walks."""
    
    def __init__(self, num_points=5000):
        """Initialize attributes of a walk."""
        self.num_points = num_points
        
        # All walks start at (0, 0).
        self.x_values = [0]
        self.y_values = [0]

    def fill_walk(self):
        """Calculate all the points in the walk."""
        
        # Keep taking steps until the walk reaches the desired length.
        while len(self.x_values) < self.num_points:
            
           
            x_direction = choice([1, -1, 1])
            x_distance = choice([0, 1, 2, 3, 4])
            x_step = x_direction * x_distance
            
            y_direction = choice([1, -1, -1])
            y_distance = choice([0, 1, 2, 3, 4])
            y_step = y_direction * y_distance
            
            # Reject moves that go nowhere.
            if x_step == 0 and y_step == 0:
                continue
            
            # Calculate the next x and y values.
            next_x = self.x_values[-1] + x_step
            next_y = self.y_values[-1] + y_step
            
            self.x_values.append(next_x)
            self.y_values.append(next_y)


rw = RandomWalkV2()
rw.fill_walk()
plt.plot(rw.x_values, rw.y_values)
plt.show()

# %%
# try it yourself 15-5
# x and y move to the same direction
class RandomWalkV3():
    """A class to generate random walks."""
    
    def __init__(self, num_points=5000):
        """Initialize attributes of a walk."""
        self.num_points = num_points
        
        # All walks start at (0, 0).
        self.x_values = [0]
        self.y_values = [0]

    def get_step(self):
         return choice([1, -1]) * choice([0, 1, 2, 3, 4])
        
    def fill_walk(self):
        """Calculate all the points in the walk."""
        
        # Keep taking steps until the walk reaches the desired length.
        while len(self.x_values) < self.num_points:
            
            x_step = self.get_step()
            y_step = self.get_step()
            
            # Reject moves that go nowhere.
            if x_step == 0 and y_step == 0:
                continue
            
            # Calculate the next x and y values.
            next_x = self.x_values[-1] + x_step
            next_y = self.y_values[-1] + y_step
            
            self.x_values.append(next_x)
            self.y_values.append(next_y)


rw = RandomWalkV3()
rw.fill_walk()
plt.plot(rw.x_values, rw.y_values)
plt.show()

# %%
# try it yourself 16-1
import csv
from datetime import datetime

sfo_hi, sfo_lo, dv_hi, dv_lo, dates = [], [], [], [], []
with open('./sfo.csv') as f: 
    reader = csv.reader(f)
    next(reader)
    for row in reader:
        dt = datetime.strptime("2018-11-" + str(row[0]), "%Y-%m-%d")
        dates.append(dt)
        sfo_hi.append(int(row[1]))
        sfo_lo.append(int(row[3]))

        
plt.figure(dpi=128, figsize=(20, 6))
plt.plot(dates, sfo_hi, c='red', alpha=0.5)
plt.plot(dates, sfo_lo, c='blue', alpha=0.5)
plt.fill_between(dates, sfo_hi, sfo_lo, facecolor='blue', alpha=0.1)
plt.title("2018 Nov high and low temperatures - SFO")
plt.show()

with open('./dv.csv') as f: 
    reader = csv.reader(f)
    next(reader)
    for row in reader:
        dv_hi.append(int(row[1]))
        dv_lo.append(int(row[3]))
        
plt.figure(dpi=128, figsize=(20, 6))
plt.plot(dates, dv_hi, c='red', alpha=0.5)
plt.plot(dates, dv_lo, c='blue', alpha=0.5)
plt.fill_between(dates, dv_hi, dv_lo, facecolor='blue', alpha=0.1)
plt.title("2018 Nov high and low temperatures - Death Valley")
plt.show()

# %%
# try it yourself 16-2
sitka_hi, sitka_lo, dv_hi, dv_lo, dates = [], [], [], [], []
with open('./sitka.csv') as f: 
    reader = csv.reader(f)
    next(reader)
    for row in reader:
        dt = datetime.strptime("2018-11-" + str(row[0]), "%Y-%m-%d")
        dates.append(dt)
        sitka_hi.append(int(row[1]))
        sitka_lo.append(int(row[3]))
        
plt.figure(dpi=128, figsize=(20, 6))
plt.ylim(25, 80)
plt.plot(dates, sitka_hi, c='red', alpha=0.5)
plt.plot(dates, sitka_lo, c='blue', alpha=0.5)
plt.fill_between(dates, sitka_hi, sitka_lo, facecolor='blue', alpha=0.1)
plt.title("2018 Nov high and low temperatures - Sitka")
plt.show()

with open('./dv.csv') as f: 
    reader = csv.reader(f)
    next(reader)
    for row in reader:
        dv_hi.append(int(row[1]))
        dv_lo.append(int(row[3]))
        
plt.figure(dpi=128, figsize=(20, 6))
plt.ylim(25, 80)
plt.plot(dates, dv_hi, c='red', alpha=0.5)
plt.plot(dates, dv_lo, c='blue', alpha=0.5)
plt.fill_between(dates, dv_hi, dv_lo, facecolor='blue', alpha=0.1)
plt.title("2018 Nov high and low temperatures - Death Valley")
plt.show()

# %%
# try it yourself 16-3
precipation, dates = [], []
with open('./kirkland.csv') as f: 
    reader = csv.reader(f)
    next(reader)
    for row in reader:
        dt = datetime.strptime("2018-11-" + str(row[0]), "%Y-%m-%d")
        dates.append(dt)
        precipation.append(float(row[-2]))
        
plt.figure(dpi=128, figsize=(20, 6))
plt.plot(dates, precipation, c='blue', alpha=0.5)
plt.title("2018 Nov precipation - Kirkland")
plt.show()

# %%
# try it yourself 16-4
barrow_hi, barrow_lo, dates = [], [], []
with open('./sitka.csv') as f: 
    reader = csv.reader(f)
    next(reader)
    for row in reader:
        dt = datetime.strptime("2018-11-" + str(row[0]), "%Y-%m-%d")
        dates.append(dt)
        barrow_hi.append(int(row[1]))
        barrow_lo.append(int(row[3]))
        
plt.figure(dpi=128, figsize=(20, 6))
plt.plot(dates, sitka_hi, c='red', alpha=0.5)
plt.plot(dates, sitka_lo, c='blue', alpha=0.5)
plt.fill_between(dates, sitka_hi, sitka_lo, facecolor='blue', alpha=0.1)
plt.title("2018 Nov high and low temperatures - Barrow")
plt.show()

# %%
# part B
# 8-1 
import pandas as pd

df = pd.read_csv('./8-1/8-1_Multi.csv')
df['Cameras'] = df['Cameras'].map(lambda x: float(x.replace(',','')))
df['Laptops'] = df['Laptops'].map(lambda x: float(x.replace(',','')))
df['Printers'] = df['Printers'].map(lambda x: float(x.replace(',','')))
df['Desktops'] = df['Desktops'].map(lambda x: float(x.replace(',','')))

df.plot(kind='bar', x='Month', y=['Cameras', 'Laptops', 'Printers', 'Desktops'], legend=False)
plt.grid(zorder=0)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# %%
df = pd.read_csv('./8-1/8-1_Pie.csv')
df['Total Sales'] = df['Total Sales'].map(lambda x: float(x.replace(',','').replace('$','')))
df = df.set_index('Product')
df.plot(kind='pie', x='Product', y='Total Sales', legend=False)
plt.grid(zorder=0)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
